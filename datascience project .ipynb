# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
mydata = pd.read_csv('C:/Users/lenovo/Desktop/data.csv')

# %%
#first five rows of the data has been printed
mydata.head()
# Out:
#                          Timestamp  Age  Gender         Education  \
# 0  2022/02/20 12:04:48 pm GMT+5:30   19    Male  Under Graduation
# 1   2022/02/20 6:09:47 pm GMT+5:30   19  Female  Under Graduation
# 2   2022/02/22 8:42:40 pm GMT+5:30   19  Female  Under Graduation
# 3   2022/02/22 9:28:12 pm GMT+5:30   22  Female   Post Graduation
# 4   2022/02/22 9:31:51 pm GMT+5:30   20  Female  Under Graduation
#
#       Family Income Highest level of education you want to pursue  \
# 0     300000-600000                                 Post Graduate
# 1     100000-300000                                Under Graduate
# 2     100000-300000                                Under Graduate
# 3  Less than 100000                                 Post Graduate
# 4     100000-300000                                 Post Graduate
#
#   Present City Means of Transportation you use(most frequently)  \
# 0      Kolkata                          Auto/ Electric Rickshaw
# ...

# %%
# It will read 15 rows  and print as an output
mydata.head(15)
# Out:
#                           Timestamp  Age  Gender         Education  \
# 0   2022/02/20 12:04:48 pm GMT+5:30   19    Male  Under Graduation
# 1    2022/02/20 6:09:47 pm GMT+5:30   19  Female  Under Graduation
# 2    2022/02/22 8:42:40 pm GMT+5:30   19  Female  Under Graduation
# 3    2022/02/22 9:28:12 pm GMT+5:30   22  Female   Post Graduation
# 4    2022/02/22 9:31:51 pm GMT+5:30   20  Female  Under Graduation
# 5    2022/02/22 9:35:53 pm GMT+5:30   19  Female  Under Graduation
# 6    2022/02/22 9:47:50 pm GMT+5:30   19    Male  Under Graduation
# 7    2022/02/22 9:48:15 pm GMT+5:30   19  Female  Under Graduation
# 8    2022/02/22 9:53:28 pm GMT+5:30   34    Male   Post Graduation
# 9    2022/02/22 9:54:19 pm GMT+5:30   21  Female  Under Graduation
# 10   2022/02/22 9:59:34 pm GMT+5:30   18  Female  Under Graduation
# 11  2022/02/22 10:06:45 pm GMT+5:30   19  Female  Under Graduation
# 12  2022/02/22 10:07:06 pm GMT+5:30   19  Female  Under Graduation
# ...

# %%
mydata.describe()
# Out:
#              Age
# count  42.000000
# mean   20.071429
# std     3.897422
# min    18.000000
# 25%    19.000000
# 50%    19.000000
# 75%    20.000000
# max    39.000000

# %%
mydata.describe().T
# Out:
#      count       mean       std   min   25%   50%   75%   max
# Age   42.0  20.071429  3.897422  18.0  19.0  19.0  20.0  39.0

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 12 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Timestamp                                                                   42 non-null     object
#  1   Age                                                                         42 non-null     int64
#  2   Gender                                                                      42 non-null     object
#  3   Education                                                                   42 non-null     object
#  4   Family Income                                                               42 non-null     object
#  5   Highest level of education you want to pursue                               42 non-null     object
# ...

# %%
mydata.shape
# Out:
# (42, 12)

# %%
mydata.isna()
# Out:
#     Timestamp    Age  Gender  Education  Family Income  \
# 0       False  False   False      False          False
# 1       False  False   False      False          False
# 2       False  False   False      False          False
# 3       False  False   False      False          False
# 4       False  False   False      False          False
# 5       False  False   False      False          False
# 6       False  False   False      False          False
# 7       False  False   False      False          False
# 8       False  False   False      False          False
# 9       False  False   False      False          False
# 10      False  False   False      False          False
# 11      False  False   False      False          False
# 12      False  False   False      False          False
# 13      False  False   False      False          False
# 14      False  False   False      False          False
# 15      False  False   False      False          False
# ...

# %%
# %matplotlib inline

# %%
import matplotlib as plt

# %%
mydata.hist
# Out:
# <bound method hist_frame of                           Timestamp  Age  Gender         Education  \
# 0   2022/02/20 12:04:48 pm GMT+5:30   19    Male  Under Graduation
# 1    2022/02/20 6:09:47 pm GMT+5:30   19  Female  Under Graduation
# 2    2022/02/22 8:42:40 pm GMT+5:30   19  Female  Under Graduation
# 3    2022/02/22 9:28:12 pm GMT+5:30   22  Female   Post Graduation
# 4    2022/02/22 9:31:51 pm GMT+5:30   20  Female  Under Graduation
# 5    2022/02/22 9:35:53 pm GMT+5:30   19  Female  Under Graduation
# 6    2022/02/22 9:47:50 pm GMT+5:30   19    Male  Under Graduation
# 7    2022/02/22 9:48:15 pm GMT+5:30   19  Female  Under Graduation
# 8    2022/02/22 9:53:28 pm GMT+5:30   34    Male   Post Graduation
# 9    2022/02/22 9:54:19 pm GMT+5:30   21  Female  Under Graduation
# 10   2022/02/22 9:59:34 pm GMT+5:30   18  Female  Under Graduation
# 11  2022/02/22 10:06:45 pm GMT+5:30   19  Female  Under Graduation
# 12  2022/02/22 10:07:06 pm GMT+5:30   19  Female  Under Graduation
# ...

# %%
mydata.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# plt.hist(mydata)

# %%
import xlrd

# %%
mydata.shape
# Out:
# (42, 12)

# %%
import pandas as pd
import xlrd
df = pd.read_csv('C:/Users/lenovo/Desktop/data.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(mydata['Age'])
# Out:
# (array([37.,  2.,  1.,  0.,  0.,  0.,  0.,  1.,  0.,  1.]),
#  array([18. , 20.1, 22.2, 24.3, 26.4, 28.5, 30.6, 32.7, 34.8, 36.9, 39. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mydata['Present City'])
# Out:
# (array([20.,  4.,  2.,  2.,  6.,  1.,  3.,  1.,  1.,  2.]),
#  array([ 0. ,  1.3,  2.6,  3.9,  5.2,  6.5,  7.8,  9.1, 10.4, 11.7, 13. ]),
#  <BarContainer object of 10 artists>)

# %%
avg = mydata['Age'].mean()

# %%
#Analyzing the gender ratios as per the ages
pd.crosstab(mydata['Age'], mydata['Gender']).T
# Out:
# Age     18  19  20  21  22  23  34  39
# Gender
# Female   5   9   3   1   1   0   0   0
# Male     3  11   6   0   0   1   1   1

# %%
import seaborn as sns

# %%
sns.boxplot(x='Age',y='Gender',data=mydata,hue='Gender')
plt.show()

# %%
mydata.hist(by='Gender',column = 'Family Income')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Family Income')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
mydata.hist(by='Present City',column = 'Means of Transportation you use(most frequently)',figsize=(50,50))
# Out:
# array([[<AxesSubplot:title={'center':'Bangalore'}>,
#         <AxesSubplot:title={'center':'Bhopal '}>,
#         <AxesSubplot:title={'center':'Delhi'}>,
#         <AxesSubplot:title={'center':'Delhi '}>],
#        [<AxesSubplot:title={'center':'Greater Noida'}>,
#         <AxesSubplot:title={'center':'Gurgaon '}>,
#         <AxesSubplot:title={'center':'Jamshedpur '}>,
#         <AxesSubplot:title={'center':'Kolkata'}>],
#        [<AxesSubplot:title={'center':'Kolkata '}>,
#         <AxesSubplot:title={'center':'New Delhi'}>,
#         <AxesSubplot:title={'center':'Noida'}>,
#         <AxesSubplot:title={'center':'Patna'}>],
#        [<AxesSubplot:title={'center':'Patna, Bihar '}>,
#         <AxesSubplot:title={'center':'Pune'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
from pylab import *

# %%
sns.countplot(x='Education',hue = 'Gender',data = mydata)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(50,25))
sns.countplot(x='City you want to migrate to / already migrated to',hue = 'Challenges faced in new city(if already migrated)',data = mydata )
# Out:
# <AxesSubplot:xlabel='City you want to migrate to / already migrated to', ylabel='count'>

# %%
np.random.seed(0)
x=np.random.random(100)
subplot(2,2,1)
ax=sns.displot(x)

# %%
pd.pivot_table(mydata, index=['Age', 'Gender'],
                     columns=[ 'Present City'], aggfunc=len)
# Out:
#              Challenges faced in new city(if already migrated)                \
# Present City                                         Bangalore Bhopal  Delhi
# Age Gender
# 18  Female                                                 NaN     NaN   1.0
#     Male                                                   NaN     NaN   NaN
# 19  Female                                                 NaN     NaN   1.0
#     Male                                                   1.0     NaN   NaN
# 20  Female                                                 NaN     1.0   1.0
#     Male                                                   NaN     NaN   NaN
# 21  Female                                                 NaN     NaN   NaN
# 22  Female                                                 NaN     NaN   1.0
# 23  Male                                                   NaN     NaN   NaN
# 34  Male                                                   NaN     NaN   NaN
# ...

# %%
plt.figure(figsize=(30,30))
sns.pairplot(mydata)

# %%
sns.pairplot(mydata,vars=["Present City","Means of Transportation you use(most frequently)"])

# %%
sns.pairplot(mydata,diag_kind = "kde")

# %%
sns.pairplot(mydata,hue = 'Education')

# %%
sns.pairplot(mydata,plot_kws = dict(fill='false'),hue = 'Education')

# %%
#will take only float or integer values
sns.distplot(mydata['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
corr=mydata.corr()
corr
# Out:
#      Age
# Age  1.0

# %%
corr = mydata.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='Gender', y='Means of Transportation you use(most frequently)',data=mydata, hue = 'Age')
plt.show()
